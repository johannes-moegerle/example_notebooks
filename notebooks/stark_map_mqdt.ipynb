# %% [markdown]
# # Simple Example of calculating Stark maps

# %%
import matplotlib.pyplot as plt
import numpy as np
import pairinteraction.backend.double as pi

# %%
pi.initialize_global_database(download_missing=True)
# Out:
# [2025-01-10 09:33:23.474 2635568] [info] [Database.cpp:201] Accessing database repository path: /repos/pairinteraction/database-sqdt/releases/latest
# [2025-01-10 09:33:23.654 2635568] [info] [Database.cpp:236] Using cached overview of available tables.
# [2025-01-10 09:33:23.655 2635568] [info] [Database.cpp:201] Accessing database repository path: /repos/pairinteraction/database-mqdt/releases/latest
# [2025-01-10 09:33:23.670 2635568] [info] [Database.cpp:236] Using cached overview of available tables.
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:292] Availability of database tables for species and Wigner 3j symbols:
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Yb173_mqdt (locally available: false, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Sr88_mqdt (locally available: false, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Yb171_mqdt (locally available: true, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Sr88_triplet (locally available: false, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Sr88_singlet (locally available: false, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Sr87_mqdt (locally available: true, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Rb (locally available: true, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:295] * Yb174_mqdt (locally available: true, up to date: false, fully downloaded: false)
# [2025-01-10 09:33:24.159 2635568] [info] [Database.cpp:298] * Wigner 3j symbols (locally available: true, up to date: true)

# %%
ket = pi.KetAtom("Yb174_mqdt", nu=60, l=1, m=1)
print(f"Ket of interest: {ket}")
ket_energy = ket.get_energy(unit="GHz")
basis = pi.BasisAtom("Yb174_mqdt", nu=(ket.nu - 10, ket.nu + 10), l=(0, 2))
print(f"Number of basis states: {basis.number_of_states}")

electric_fields = np.linspace(0, 8, 50)
systems = [pi.SystemAtom(basis).set_electric_field([0, 0, e], unit="V/cm") for e in electric_fields]

# Diagonalize the systems in parallel
pi.diagonalize(systems, diagonalizer="Eigen", sort_by_energy=True)

eigenvalues = np.array([system.get_eigenvalues(unit="GHz") for system in systems])
overlaps = np.array([system.get_eigenbasis().get_overlaps(ket) for system in systems])
# Out:
# [2025-01-10 09:33:24.213 2635568] [infoKet of interest: Yb174:S=0.4,nu=60.0,L=1.0,J=1,1
# Number of basis states: 723
# ] [Database.cpp:1308] Updating database `Yb174_mqdt_states` from version 1 to version 2.
# [2025-01-10 09:33:24.901 2635568] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635706] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635707] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635713] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635709] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635710] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635714] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635711] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635715] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635708] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635712] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.
# [2025-01-10 09:33:24.902 2635716] [info] [Database.cpp:1308] Updating database `Yb174_mqdt_matrix_elements_d` from version 1 to version 2.

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12, 5))

for ax in axs:
    ax.set_xlabel("Electric Field [V/cm]")
    ax.set_ylabel("Energy [GHz]")

axs[0].plot(electric_fields, eigenvalues - ket_energy, c="k", lw=0.25)

axs[1].scatter(np.repeat(electric_fields, eigenvalues.shape[1]), eigenvalues - ket_energy, c=overlaps, s=10)
axs[1].set_ylim(-10, 30)

plt.show()
